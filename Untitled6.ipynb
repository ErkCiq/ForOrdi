# %%
import pandas as pd
df = pd.read_csv('shopping_behavior.csv')
df.head(5)
df.tail(5)
print(df['Age'].unique())
print(df['Age'].value_counts())
# Out:
# [55 19 50 21 45 46 63 27 26 57 53 30 61 65 64 25 52 66 31 56 18 38 54 33
#  36 35 29 70 69 67 20 39 42 68 49 59 47 40 41 48 22 24 44 37 58 32 62 51
#  28 43 34 23 60]
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 54    83
# 27    83
# 50    83
# 62    83
# 32    82
# 58    81
# 19    81
# 42    80
# 31    79
# 28    79
# 43    79
# 37    77
# 29    76
# 46    76
# 63    75
# 59    75
# 68    75
# 56    74
# 36    74
# 52    73
# 64    73
# 55    73
# 51    72
# 65    72
# 45    72
# 40    72
# 35    72
# 47    71
# 66    71
# 30    71
# 23    71
# 53    70
# 38    70
# 18    69
# 26    69
# 21    69
# 34    68
# 39    68
# 48    68
# 24    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
print(df.isna().sum())
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
print(df['Age'].value_counts())
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 54    83
# 27    83
# 50    83
# 62    83
# 32    82
# 58    81
# 19    81
# 42    80
# 31    79
# 28    79
# 43    79
# 37    77
# 29    76
# 46    76
# 63    75
# 59    75
# 68    75
# 56    74
# 36    74
# 52    73
# 64    73
# 55    73
# 51    72
# 65    72
# 45    72
# 40    72
# 35    72
# 47    71
# 66    71
# 30    71
# 23    71
# 53    70
# 38    70
# 18    69
# 26    69
# 21    69
# 34    68
# 39    68
# 48    68
# 24    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df['Age'].hist(bins=10)
# Out:
# <Axes: >

# %%
plt.bar(df['Age'], df['Purchase Amount (USD)'])
# Out:
# <BarContainer object of 3900 artists>

# %%
print(df['Purchase Amount (USD)'])
# Out:
# 0       53
# 1       64
# 2       73
# 3       90
# 4       49
#         ..
# 3895    28
# 3896    49
# 3897    33
# 3898    77
# 3899    81
# Name: Purchase Amount (USD), Length: 3900, dtype: int64

# %%
plt.scatter(df['Season'],df['Item Purchased'])
plt.show()

# %%
plt.bar(df['Season'],df['Purchase Amount (USD)'])
# Out:
# <BarContainer object of 3900 artists>

# %%
df.groupby('Item Purchased')['Purchase Amount (USD)'].mean()
# Out:
# Item Purchased
# Backpack      60.391608
# Belt          59.844720
# Blouse        60.877193
# Boots         62.625000
# Coat          57.608696
# Dress         62.168675
# Gloves        60.550000
# Handbag       57.888889
# Hat           60.876623
# Hoodie        58.059603
# Jacket        56.742331
# Jeans         60.870968
# Jewelry       58.538012
# Pants         59.005848
# Sandals       57.500000
# Scarf         60.898089
# Shirt         61.136095
# Shoes         61.600000
# Shorts        60.082803
# Skirt         59.506329
# Sneakers      59.551724
# Socks         58.188679
# Sunglasses    59.931677
# Sweater       57.695122
# T-shirt       62.911565
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby('Category')['Purchase Amount (USD)'].agg(['mean','min'])
# Out:
#                   mean  min
# Category
# Accessories  59.838710   20
# Clothing     60.025331   20
# Footwear     60.255426   20
# Outerwear    57.172840   20

# %%
df.groupby(['Age','Gender','Purchase Amount (USD)'])['Shipping Type'].sum().reset_index()
# Out:
#       Age  Gender  Purchase Amount (USD)               Shipping Type
# 0      18  Female                     25                Next Day Air
# 1      18  Female                     28                     Express
# 2      18  Female                     29              2-Day Shipping
# 3      18  Female                     31                     Express
# 4      18  Female                     32                     Express
# ...   ...     ...                    ...                         ...
# 3076   70    Male                     85                    Standard
# 3077   70    Male                     94               Free Shipping
# 3078   70    Male                     95  Store Pickup2-Day Shipping
# 3079   70    Male                     97                     Express
# 3080   70    Male                     99               Free Shipping
#
# [3081 rows x 4 columns]
